# %%
import xarray as xr
import matplotlib.pyplot as plt

# %%
da = xr.open_dataset("example_data/tas_12km_boxplots_20491201-20791130_annual.nc").squeeze().tas

# %%
plt.violinplot(da.values)
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x7fb1e3ecf4f0>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x7fb1e3ecf490>,
#  'cmins': <matplotlib.collections.LineCollection at 0x7fb1e3ecfb80>,
#  'cbars': <matplotlib.collections.LineCollection at 0x7fb1e3ecff40>}
